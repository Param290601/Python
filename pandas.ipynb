# %%
 from google.colab import files 

uploaded = files.upload()
# Out:
#      <input type="file" id="files-bfd0ce86-5b20-4869-85f7-6a4cbf5ce9c2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-bfd0ce86-5b20-4869-85f7-6a4cbf5ce9c2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df = pd.read_csv('netflix_titles.csv')
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
df.tail(1)
# Out:
#      show_id   type   title     director  \
# 8806   s8807  Movie  Zubaan  Mozez Singh
#
#                                                    cast country  \
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...   India
#
#          date_added  release_year rating duration  \
# 8806  March 2, 2019          2015  TV-14  111 min
#
#                                            listed_in  \
# 8806  Dramas, International Movies, Music & Musicals
#
#                                             description
# 8806  A scrappy but poor boy worms his way into a ty...

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
df.show_id
# Out:
# 0          s1
# 1          s2
# 2          s3
# 3          s4
# 4          s5
#         ...
# 8802    s8803
# 8803    s8804
# 8804    s8805
# 8805    s8806
# 8806    s8807
# Name: show_id, Length: 8807, dtype: object

# %%
df['release_year'] = '2021'

# %%
df.describe()
# Out:
#        show_id   type                 title       director  \
# count     8807   8807                  8807           6173
# unique    8807      2                  8807           4528
# top         s1  Movie  Dick Johnson Is Dead  Rajiv Chilaka
# freq         1   6131                     1             19
#
#                       cast        country       date_added release_year  \
# count                 7982           7976             8797         8807
# unique                7692            748             1767            1
# top     David Attenborough  United States  January 1, 2020         2021
# freq                    19           2818              109         8807
#
#        rating  duration                     listed_in  \
# count    8803      8804                          8807
# unique     17       220                           514
# top     TV-MA  1 Season  Dramas, International Movies
# freq     3207      1793                           362
#
# ...

# %%
df[df.release_year == '2021']
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df[['show_id','type','title']].head(5) [df.release_year == '2021']
# Out:
# <ipython-input-19-372bfdb5107a>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df[['show_id','type','title']].head(5) [df.release_year == '2021']
#   show_id     type                  title
# 0      s1    Movie   Dick Johnson Is Dead
# 1      s2  TV Show          Blood & Water
# 2      s3  TV Show              Ganglands
# 3      s4  TV Show  Jailbirds New Orleans
# 4      s5  TV Show           Kota Factory

# %%
import numpy as np
af = pd.Series(np.random.rand(50))

# %%
af
# Out:
# 0     0.932802
# 1     0.860648
# 2     0.110014
# 3     0.088382
# 4     0.952325
# 5     0.585202
# 6     0.631281
# 7     0.559201
# 8     0.329654
# 9     0.347593
# 10    0.527171
# 11    0.585740
# 12    0.877257
# 13    0.817642
# 14    0.765698
# 15    0.383612
# 16    0.508332
# 17    0.717245
# 18    0.772132
# 19    0.097232
# 20    0.337482
# 21    0.879661
# 22    0.576329
# 23    0.009779
# 24    0.687898
# 25    0.263353
# 26    0.606603
# 27    0.003678
# 28    0.323458
# 29    0.653149
# 30    0.078873
# 31    0.922619
# 32    0.260124
# 33    0.879924
# 34    0.805487
# 35    0.032466
# 36    0.397501
# 37    0.524298
# 38    0.521911
# 39    0.886987
# 40    0.880381
# 41    0.071290
# 42    0.893068
# 43    0.636179
# 44    0.009651
# 45    0.258963
# 46    0.255738
# 47    0.691622
# 48    0.177799
# 49    0.219331
# dtype: float64

# %%
data = pd.DataFrame(np.random.rand(100,3), index=np.arange(100))

# %%
data
# Out:
#            0         1         2
# 0   0.815509  0.011043  0.222564
# 1   0.764501  0.924846  0.920669
# 2   0.809098  0.888300  0.918754
# 3   0.701695  0.944127  0.093863
# 4   0.291402  0.522183  0.405260
# ..       ...       ...       ...
# 95  0.230823  0.798065  0.086281
# 96  0.621164  0.840455  0.169391
# 97  0.840644  0.271727  0.706367
# 98  0.345482  0.307206  0.596493
# 99  0.238262  0.965121  0.900721
#
# [100 rows x 3 columns]

# %%
data.describe()
# Out:
#                 0           1           2
# count  100.000000  100.000000  100.000000
# mean     0.483121    0.501291    0.482206
# std      0.294407    0.293613    0.280383
# min      0.019510    0.001567    0.000762
# 25%      0.226987    0.255205    0.243837
# 50%      0.492262    0.502922    0.468461
# 75%      0.758111    0.748007    0.701996
# max      0.997527    0.993474    0.981374

# %%
data.T
# Out:
#          0         1         2         3         4         5         6   \
# 0  0.815509  0.764501  0.809098  0.701695  0.291402  0.395152  0.132450
# 1  0.011043  0.924846  0.888300  0.944127  0.522183  0.351313  0.402127
# 2  0.222564  0.920669  0.918754  0.093863  0.405260  0.713299  0.523103
#
#          7         8         9   ...        90        91        92        93  \
# 0  0.215479  0.947289  0.917209  ...  0.068800  0.451562  0.256639  0.248566
# 1  0.673667  0.346813  0.701135  ...  0.496969  0.347117  0.764639  0.796600
# 2  0.430184  0.642537  0.627087  ...  0.164666  0.082186  0.555906  0.852141
#
#          94        95        96        97        98        99
# 0  0.545244  0.230823  0.621164  0.840644  0.345482  0.238262
# 1  0.660327  0.798065  0.840455  0.271727  0.307206  0.965121
# 2  0.643044  0.086281  0.169391  0.706367  0.596493  0.900721
#
# [3 rows x 100 columns]

# %%
data.sort_index(axis=0,ascending = False)
# Out:
#            0         1         2
# 99  0.238262  0.965121  0.900721
# 98  0.345482  0.307206  0.596493
# 97  0.840644  0.271727  0.706367
# 96  0.621164  0.840455  0.169391
# 95  0.230823  0.798065  0.086281
# ..       ...       ...       ...
# 4   0.291402  0.522183  0.405260
# 3   0.701695  0.944127  0.093863
# 2   0.809098  0.888300  0.918754
# 1   0.764501  0.924846  0.920669
# 0   0.815509  0.011043  0.222564
#
# [100 rows x 3 columns]

# %%
data.sort_index(axis=0)
# Out:
#            0         1         2
# 0   0.815509  0.011043  0.222564
# 1   0.764501  0.924846  0.920669
# 2   0.809098  0.888300  0.918754
# 3   0.701695  0.944127  0.093863
# 4   0.291402  0.522183  0.405260
# ..       ...       ...       ...
# 95  0.230823  0.798065  0.086281
# 96  0.621164  0.840455  0.169391
# 97  0.840644  0.271727  0.706367
# 98  0.345482  0.307206  0.596493
# 99  0.238262  0.965121  0.900721
#
# [100 rows x 3 columns]

# %%
data.loc[0][0] = 153

# %%
data
# Out:
#              0         1         2
# 0   153.000000  0.011043  0.222564
# 1     0.764501  0.924846  0.920669
# 2     0.809098  0.888300  0.918754
# 3     0.701695  0.944127  0.093863
# 4     0.291402  0.522183  0.405260
# ..         ...       ...       ...
# 95    0.230823  0.798065  0.086281
# 96    0.621164  0.840455  0.169391
# 97    0.840644  0.271727  0.706367
# 98    0.345482  0.307206  0.596493
# 99    0.238262  0.965121  0.900721
#
# [100 rows x 3 columns]

# %% [markdown]
# data.columns = list('ABC')

# %%
data
# Out:
#              A         B         C
# 0   153.000000  0.011043  0.222564
# 1     0.764501  0.924846  0.920669
# 2     0.809098  0.888300  0.918754
# 3     0.701695  0.944127  0.093863
# 4     0.291402  0.522183  0.405260
# ..         ...       ...       ...
# 95    0.230823  0.798065  0.086281
# 96    0.621164  0.840455  0.169391
# 97    0.840644  0.271727  0.706367
# 98    0.345482  0.307206  0.596493
# 99    0.238262  0.965121  0.900721
#
# [100 rows x 3 columns]

# %%
data.iloc[[0,5], [1,2]]
# Out:
#           B         C
# 0  0.011043  0.222564
# 5  0.351313  0.713299

# %%
data.iloc[0,1]
# Out:
# 0.01104329263806525
